# %%
import pandas as pd
import pyodbc

conn = pyodbc.connect(
    "DRIVER={ODBC Driver 17 for SQL Server};"
    "SERVER=ITDSTANDBY-LAP\\MSSQLSERVER01;"
    "DATABASE=Sales_New;"
    "Trusted_Connection=yes;"
)

# %% [markdown]
# ## Bronze Data loading

# %%
query = """
SELECT *
FROM bronze.vw_sales
"""
df_bronze_sales = pd.read_sql(query, conn)
# Out:
# C:\Users\ITDSTANDBY\AppData\Local\Temp\ipykernel_16240\615718117.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_bronze_sales = pd.read_sql(query, conn)

# %%
df_bronze_sales.to_parquet("bronze_vw_sales.parquet", index=False)

# %% [markdown]
# ## Silver data to parquet

# %%
query = """
SELECT *
FROM silver.vw_sales
"""
df_silver_sales = pd.read_sql(query, conn)
# Out:
# C:\Users\ITDSTANDBY\AppData\Local\Temp\ipykernel_16240\1089870571.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_silver_sales = pd.read_sql(query, conn)

# %%
df_silver_sales.to_parquet("silver_vw_sales.parquet", index=False)

# %% [markdown]
# ## Gold data to parquet

# %%
query = """
SELECT *
FROM gold.vw_dim_customer_group
"""
df_gold_dim_customer_group = pd.read_sql(query, conn)
# Out:
# C:\Users\ITDSTANDBY\AppData\Local\Temp\ipykernel_16240\2875188296.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_gold_dim_customer_group = pd.read_sql(query, conn)

# %%
df_gold_dim_customer_group.to_parquet(
    "gold_vw_dim_customer_group.parquet", index=False
)

# %%
query = """
SELECT *
FROM gold.vw_dim_date
"""
df_gold_dim_date = pd.read_sql(query, conn)
# Out:
# C:\Users\ITDSTANDBY\AppData\Local\Temp\ipykernel_16240\1620507378.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_gold_dim_date = pd.read_sql(query, conn)

# %%
df_gold_dim_date.to_parquet("gold_vw_dim_date.parquet", index=False)

# %%
query = """
SELECT *
FROM gold.vw_dim_item
"""
df_gold_dim_item = pd.read_sql(query, conn)
# Out:
# C:\Users\ITDSTANDBY\AppData\Local\Temp\ipykernel_16240\228265111.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_gold_dim_item = pd.read_sql(query, conn)

# %%
df_gold_dim_item.to_parquet("gold_vw_dim_item.parquet", index=False)

# %%
query = """
SELECT *
FROM gold.vw_dim_store
"""
df_gold_dim_store = pd.read_sql(query, conn)
# Out:
# C:\Users\ITDSTANDBY\AppData\Local\Temp\ipykernel_16240\3170047827.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_gold_dim_store = pd.read_sql(query, conn)

# %%
df_gold_dim_store.to_parquet("gold_vw_dim_store.parquet", index=False)

# %%
query = """
SELECT *
FROM gold.vw_discount_analysis
"""
df_gold_discount_analysis = pd.read_sql(query, conn)
# Out:
# C:\Users\ITDSTANDBY\AppData\Local\Temp\ipykernel_16240\678502784.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_gold_discount_analysis = pd.read_sql(query, conn)

# %%
df_gold_discount_analysis.to_parquet(
    "gold_vw_discount_analysis.parquet", index=False
)

# %%
query = """
SELECT *
FROM gold.vw_fact_sales_daily
"""
df_gold_fact_sales_daily = pd.read_sql(query, conn)
# Out:
# C:\Users\ITDSTANDBY\AppData\Local\Temp\ipykernel_16240\3166121847.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_gold_fact_sales_daily = pd.read_sql(query, conn)

# %%
df_gold_fact_sales_daily.to_parquet(
    "gold_vw_fact_sales_daily.parquet", index=False
)

# %%
query = """
SELECT *
FROM gold.vw_sales_summary_monthly
"""
df_gold_sales_summary_monthly = pd.read_sql(query, conn)
# Out:
# C:\Users\ITDSTANDBY\AppData\Local\Temp\ipykernel_16240\891712507.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_gold_sales_summary_monthly = pd.read_sql(query, conn)

# %%
df_gold_sales_summary_monthly.to_parquet(
    "gold_vw_sales_summary_monthly.parquet", index=False
)

# %%
query = """
SELECT *
FROM gold.vw_top_selling_items
"""
df_gold_top_selling_items = pd.read_sql(query, conn)
# Out:
# C:\Users\ITDSTANDBY\AppData\Local\Temp\ipykernel_16240\1158351091.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_gold_top_selling_items = pd.read_sql(query, conn)

# %%
df_gold_top_selling_items.to_parquet(
    "gold_vw_top_selling_items.parquet", index=False
)
